# %%
from card import Card, Face, Suit
from deck import Deck

my_card = Card(Face.TEN, Suit.DIAMONDS)
print("my_card:", my_card)
print("my_card.get_image_path():", my_card.get_image_path())
my_card.download_image()
my_card.display_image()

my_deck = Deck()
# Out:
# my_card: images/0D.png
# my_card.get_image_path(): images/0D.png
# https://deckofcardsapi.com/static/img/0D.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=226x314>
