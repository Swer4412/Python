# %%
import pandas as pd

# Carica il dataset
url = "titanic.csv"
df = pd.read_csv(url)
df.head()
df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14,5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26,5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male    27      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male    29      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14,4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14,4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7,2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7,2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7,8750   NaN        S  NaN    NaN       NaN

# %%
# visualizza le informazioni del dataframe
df.info()
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# stampa il numero di righe e di colonne del dataframe
df.shape
# Out:
# (1309, 14)

# %%
# descrivi le variabili statistiche minimo, massimo, percentili ecc
df.describe()
# Out:
#             pclass     survived        sibsp        parch        body
# count  1309.000000  1309.000000  1309.000000  1309.000000  121.000000
# mean      2.294882     0.381971     0.498854     0.385027  160.809917
# std       0.837836     0.486055     1.041658     0.865560   97.696922
# min       1.000000     0.000000     0.000000     0.000000    1.000000
# 25%       2.000000     0.000000     0.000000     0.000000   72.000000
# 50%       3.000000     0.000000     0.000000     0.000000  155.000000
# 75%       3.000000     1.000000     1.000000     0.000000  256.000000
# max       3.000000     1.000000     8.000000     9.000000  328.000000

# %%
# stampa i nomi delle colonne
list(df.columns)
# Out:
# ['pclass',
#  'survived',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked',
#  'boat',
#  'body',
#  'home.dest']

# %%
# crea il dizionario che fa corrispondere i caratteri C, Q ed S con i nomi corrispondenti dei porti di imbarco del Titanic
df['embarked']
# Out:
# 0       S
# 1       S
# 2       S
# 3       S
# 4       S
#        ..
# 1304    C
# 1305    C
# 1306    C
# 1307    C
# 1308    S
# Name: embarked, Length: 1309, dtype: object

# %%
# sostituisci i caratteri C, Q, S con i valori corrispondenti all'interno della colonna embarked

# %%
# conta il numero di persone imbarcate nei 3 porti di partenza
df.groupby("embarked")

# %%
# visualizza le due righe in cui manca il porto d'imbarco

# %%
# trova le righe in cui manca il codice cabina. Quante sono?

# %%
# quante sono le età mancanti?

# %%
# conta il numero di maschi e di femmine del dataset

# %%
# conta il numero di passeggeri per classe (le classi erano 3)

# %%
# conta il numnero di maschi e femmine per classe

# %%
# conta il numero di passeggeri sopravvissuti per classe e per sesso

# %%
# calcola la percentuale dei sopravvissuti e dei non sopravvissuti

# %%
# stampa le percentuali dei sopravvissuti e dei non sopravvissuti per genere

# %%
# sopravvissero di più gli sposati o i celibi/nubili? Suggerimento: crea una nuova colonna e chiamala status
# una persona è celibe/nubile se il valore nella colonna sibsp è 0

# %%
# sopravvissero di più quelli senza famiglia o con famiglia? Suggerimento: crea una nuova colonna con_famiglia
# una persona era con famiglia se il valore nella colonna parch è positivo, senza famiglia se il valore era 0
